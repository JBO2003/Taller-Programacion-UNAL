# %% [markdown]
# 1. Define a procedure histogram () that takes a list of whole numbers and prints a histogram on the screen.

# %%
def histogram(a):

  x="* "

  num=int(input("Ingrese un numero 1: "))
  numb=int(input("Ingrese un numero 2: "))

  for i in range(num):
    for j in range(numb):

        xd=((i)*x)
        xd2=((j)*x)

    print(xd)
    print(xd2, end="")

  return i
  return j

histo=[3,4,56,7,25]

a=histogram(histo)

print(a)
# Out:
# Ingrese un numero 1: 3
# Ingrese un numero 2: 4
#
# * * * *
# * * * * *
# * * * 2

# %% [markdown]
# 2. Write a longer_long () function that takes a list of words and returns the longest.

# %%
lista = ["sajkdjkas","sada","afasf","ola"]
def longer_long(lista):
  b=""
  c=""
  for i in lista:
    b+=str(len(i))
  c=list(b)
  d=max(c)
  for i in lista:
    if len(i) == int(d):
      c=print("la palabra mas larga es", i, "con", d, "caracteres")

  return c

lista = ["sajkdjkas","sada","afasf","ola"]

print(longer_long(lista))
# Out:
# la palabra mas larga es sajkdjkas con 9 caracteres
# None

# %% [markdown]
# 3. Write a program that tells the user to enter a string. The program has to evaluate the string and say how many capital letters it has.

# %%
def mayu(palabra):
  b=input("Ingrese una palabra: ")
  import string
  a=list(string.ascii_uppercase)
  c=""
  d=""
  for i in a:
    for j in b:
      if i==j:
        c+=i
  d=print("la palabra tiene", len(c), "letras mayusculas")
  return d

# %% [markdown]
# 4.Build a small program that converts binary numbers to integers.

# %%
def bindec(num):
  x=0
  y=0
  print("el binario", num)
  while(num>=1):
    d=num%10;
    num=int(num/10)
    x=x+d*pow(2,y);
    y=y+1 
  print("corresponde al numero", x)

# %%
bindec(1000)
# Out:
# el binario 1000
# corresponde al numero 8

# %% [markdown]
# 5.Create a function count_vols (), which receives a word and counts how many letters "a" it has, how many letters "e" it has, and so on until all the vowels are completed.

# %%
def l():
    global txt
    txt=(input("ingrese una palabra:  ")).lower()
def c():
    v=["a"]
    d=["e"]
    
    cont_a=0
    cont_e=0

    for i in v:
        for j in txt:
            if(i==j):
                cont_a+=1
    for r in d:
        for y in txt:
            if(r==y):
                cont_e+=1


    cont=cont_a+cont_e
    print("el numero total de vocales es: " ,cont)
    print(f"""el numero por vocal es:  
    a: {cont_a}
    e: {cont_e}
    """)
l()
c()
# Out:
# ingrese una palabra:  hola
# el numero total de vocales es:  1
# el numero por vocal es:
#     a: 1
#     e: 0

# %% [markdown]
# 6.Write a function is leap () that determines if a given year is a leap year

# %%
def es_bisiesto(anio):
  if anio is 1/400:
    return False
  elif anio is 1/100 == 0:
    return True
  elif anio is 1/4 ==0:
    return False
  else:
    return True

anio = 2020
print("¿El año", anio, "es bisiesto?:", es_bisiesto(anio))
# Out:
# ¿El año 2020 es bisiesto?: True

# %% [markdown]
# 7. Write a program that asks for two words and tells whether or not they rhyme. If the last three letters match, you have to say that they rhyme. If only the last two coincide, he has to say that they rhyme a bit and if not, that they do not rhyme.

# %%
plb1=input("Escriba la primera palabra: ")
plb2=input("Escriba la segunda palabra: ")

utp1=plb1[-3:]
utp2=plb2[-3:]
utp21=plb1[-2:]
utp22=plb2[-2:]

if utp1==utp2:
  print(" Estas palabras si riman")

elif utp21==utp22:
  print(" Estas palabras alcanzan a rimar")

else:
    print(" Estas palabras no riman")
# Out:
# Escriba la primera palabra: sharon
# Escriba la segunda palabra: arroz
#  Estas palabras no riman

# %% [markdown]
# 8.It has a program that asks the user for a dollar amount, an interest rate, and a number of years. It shows on the screen how much the initial capital will have been converted after those years if the interest rate entered is applied each year.

# %%
def calculo (dinero, inte, cant_anos):

  dlmnt=int(input("Ingrese la cantidad de dinero: "))
  intr=int(input("Ingrese el porcentaje de interés: "))
  years=int(input("¿Por cuántos años lo quiere? "))

  x=dlmnt*(1+intr/100)**years

  print(x)

  return x


dlmnt=int(input("Ingrese la cantidad de dinero: "))
intr=int(input("Ingrese el porcentaje de interés: "))
years=int(input("¿Por cuántos años lo quiere? "))

x=dlmnt*(1+intr/100)**years

print("Su resultado es:", x)
# Out:
# Ingrese la cantidad de dinero: 546
# Ingrese el porcentaje de interés: 5
# ¿Por cuántos años lo quiere? 46
# Su resultado es: 5151.104968009436

# %% [markdown]
# 9. Create an algorithm that ask for one number the (0 to 100), the program have to create a multiplication table from 0 to the selected number.

# %%
a=int(input("Ingrese un número entre 1 y 100: "))
b=a+1
for i in range(0,b):
  print(i, "x", a, "=",(i*a))
# Out:
# Ingrese un número entre 1 y 100: 99
# 0 x 99 = 0
# 1 x 99 = 99
# 2 x 99 = 198
# 3 x 99 = 297
# 4 x 99 = 396
# 5 x 99 = 495
# 6 x 99 = 594
# 7 x 99 = 693
# 8 x 99 = 792
# 9 x 99 = 891
# 10 x 99 = 990
# 11 x 99 = 1089
# 12 x 99 = 1188
# 13 x 99 = 1287
# 14 x 99 = 1386
# 15 x 99 = 1485
# 16 x 99 = 1584
# 17 x 99 = 1683
# 18 x 99 = 1782
# 19 x 99 = 1881
# 20 x 99 = 1980
# 21 x 99 = 2079
# 22 x 99 = 2178
# 23 x 99 = 2277
# 24 x 99 = 2376
# 25 x 99 = 2475
# 26 x 99 = 2574
# 27 x 99 = 2673
# 28 x 99 = 2772
# 29 x 99 = 2871
# 30 x 99 = 2970
# 31 x 99 = 3069
# 32 x 99 = 3168
# 33 x 99 = 3267
# 34 x 99 = 3366
# 35 x 99 = 3465
# 36 x 99 = 3564
# 37 x 99 = 3663
# 38 x 99 = 3762
# 39 x 99 = 3861
# 40 x 99 = 3960
# 41 x 99 = 4059
# 42 x 99 = 4158
# 43 x 99 = 4257
# 44 x 99 = 4356
# 45 x 99 = 4455
# 46 x 99 = 4554
# 47 x 99 = 4653
# 48 x 99 = 4752
# 49 x 99 = 4851
# 50 x 99 = 4950
# 51 x 99 = 5049
# 52 x 99 = 5148
# 53 x 99 = 5247
# 54 x 99 = 5346
# 55 x 99 = 5445
# 56 x 99 = 5544
# 57 x 99 = 5643
# 58 x 99 = 5742
# 59 x 99 = 5841
# 60 x 99 = 5940
# 61 x 99 = 6039
# 62 x 99 = 6138
# 63 x 99 = 6237
# 64 x 99 = 6336
# 65 x 99 = 6435
# 66 x 99 = 6534
# 67 x 99 = 6633
# 68 x 99 = 6732
# 69 x 99 = 6831
# 70 x 99 = 6930
# 71 x 99 = 7029
# 72 x 99 = 7128
# 73 x 99 = 7227
# 74 x 99 = 7326
# 75 x 99 = 7425
# 76 x 99 = 7524
# 77 x 99 = 7623
# 78 x 99 = 7722
# 79 x 99 = 7821
# 80 x 99 = 7920
# 81 x 99 = 8019
# 82 x 99 = 8118
# 83 x 99 = 8217
# 84 x 99 = 8316
# 85 x 99 = 8415
# 86 x 99 = 8514
# 87 x 99 = 8613
# 88 x 99 = 8712
# 89 x 99 = 8811
# 90 x 99 = 8910
# 91 x 99 = 9009
# 92 x 99 = 9108
# 93 x 99 = 9207
# 94 x 99 = 9306
# 95 x 99 = 9405
# 96 x 99 = 9504
# 97 x 99 = 9603
# 98 x 99 = 9702
# 99 x 99 = 9801
